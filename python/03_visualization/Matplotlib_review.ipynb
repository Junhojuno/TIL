# %%
# %matplotlib inline

# %%
# %config lnlineBackend.figure_formats = {'png','retina'}

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
y = np.random.randint(1,10,size=10)
plt.plot(y)
plt.show()

# %%
x = range(0,100,10)
plt.plot(x,y)
plt.show()

# %%
plt.plot(y, 'r*:')
plt.show()

# %%
plt.plot(y, c='deeppink', lw=1, ls='-.', marker='*', ms=25, mec='crimson', mew=3,\
        mfc='cornsilk')
plt.show()

# %%
plt.plot(y)
plt.xlim(-5,15)
plt.ylim(-10,20)
plt.show()

# %%
plt.plot(y)
plt.xticks(range(10))
plt.yticks(range(5))
plt.show()

# %%
plt.plot(y)
plt.grid(False) # 격자 제거(False)
plt.show()

# %%
y1 = np.random.randint(1,10, size=5)
y2 = np.random.randint(1,10, size=5)
y3 = np.random.randint(1,10, size=5)

x = range(5)

plt.plot(x, y1, 'bo-', x, y2, 'r*-', x, y3, 'g^:')
plt.show()

# %%
plt.plot(y)
plt.title("Title")
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.show()

# %%
import matplotlib.font_manager as fm
font_location = "C:\\Windows\Fonts\malgunbd.ttf"
font_name = fm.FontProperties(fname=font_location).get_name()
print(font_name)
mpl.rc("font", family=font_name)
# Out:
# Malgun Gothic

# %%
plt.plot(y1)
plt.title("타이틀")
plt.xlabel("x축")
plt.ylabel("y축")
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(y)
plt.show()

# %%
y = y[:5]
plt.Figure(figsize=(10,8))

plt.subplot(2,2,1)
plt.plot(y)

plt.subplot(2,2,2)
plt.plot(y1)

plt.subplot(2,2,3)
plt.plot(y2)

plt.subplot(2,2,4)
plt.plot(y3)

plt.show()

# %%
plt.bar(x,y)
plt.show()

# %%
error = np.random.randint(1,5, size=5)
plt.figure(figsize=(8,8))
plt.bar(x,y,yerr=error, alpha=0.4)
plt.show()

# %%
plt.barh(x,y, xerr=error, alpha=0.4)
plt.show()

# %%
plt.bar(x,y1)
plt.bar(x,y2)
plt.show()

# %%
labels = ["A","B","C","D","E"]
colors = ["red","deeppink","slategray","steelblue","teal"]

plt.pie(y, labels=labels, autopct="%1.2f%%", colors=colors)
plt.show()

# %%
a = np.random.rand(500)
b = np.random.rand(500)
plt.scatter(a,b)
plt.show()

# %%
c = np.random.randn(500)
d = np.random.randn(500)
plt.scatter(c,d)
plt.show()

# %%
e = np.random.randint(1,100, size=500)
f = np.random.randint(1,100, size=500)
plt.scatter(e,f)
plt.show()

# %%
a1 = np.random.randint(1,10, size=20)
a2 = np.random.randint(1,10, size=20)
colors = np.random.rand(20)
area = np.pi * np.arange(10,50,2) ** 2

plt.scatter(a1, a2, s=area, c=colors, alpha=0.5, marker="*")
plt.show()

# %%
x = np.random.rand(500)
plt.hist(x, bins=10)
plt.show()

# %%
plt.hist(x, bins=20)
print(x[:10])
plt.show()
# Out:
# [0.40177715 0.85432422 0.45510741 0.44495229 0.11183393 0.50893077
#  0.56427281 0.05994746 0.2419197  0.0030071 ]

# %%
plt.hist(x, bins=200)
print(x[:10])
plt.show()
# Out:
# [0.40177715 0.85432422 0.45510741 0.44495229 0.11183393 0.50893077
#  0.56427281 0.05994746 0.2419197  0.0030071 ]
