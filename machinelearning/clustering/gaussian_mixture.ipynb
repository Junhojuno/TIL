# %% [markdown]
# ## 가우시안 혼합 모형(mixture)

# %%
# %matplotlib inline

# %%
from numpy.random import randn

n_samples = 500

mu1 = np.array([0, 0])
mu2 = np.array([-6, 3])
sigma1 = np.array([[0., -0.1], [1.7, .4]])
sigma2 = np.eye(2)

np.random.seed(0)
X = np.r_[1.0 * np.dot(randn(n_samples, 2), sigma1) + mu1,
          0.7 * np.dot(randn(n_samples, 2), sigma2) + mu2,
         ]
plt.scatter(X[:, 0], X[:, 1], s=5)
plt.show()

# %%
from sklearn.mixture import GaussianMixture

# %%
model = GaussianMixture(n_components=2, init_params='random', random_state=0, max_iter=1)
model.fit(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# GaussianMixture(covariance_type='full', init_params='random', max_iter=1,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=0, reg_covar=1e-06, tol=0.001, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
gamma = model.predict_proba(X)

# %%
gamma
# Out:
# array([[ 0.50670305,  0.49329695],
#        [ 0.55409475,  0.44590525],
#        [ 0.50184734,  0.49815266],
#        ...,
#        [ 0.48580584,  0.51419416],
#        [ 0.4893519 ,  0.5106481 ],
#        [ 0.49036003,  0.50963997]])

# %%
plt.scatter(X[:, 0], X[:, 1], s=50, linewidth=1, edgecolors="b", cmap=plt.cm.binary, c=gamma[:, 0])
plt.show()

# %%
def plot_gaussianmixture(n, k=10):
    model = GaussianMixture(n_components=2, init_params='random', random_state=1, tol=1e-9, max_iter=n)
    model.fit(X)
    gamma = model.predict_proba(X)
    plt.scatter(X[:, 0], X[:, 1], s=50, linewidth=1, edgecolors="b", cmap=plt.cm.binary, c=gamma[:, 0])
    plt.show()
    return model

# %%
plot_gaussianmixture(5) # 5번 돌려본다.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# GaussianMixture(covariance_type='full', init_params='random', max_iter=5,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=1, reg_covar=1e-06, tol=1e-09, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
plot_gaussianmixture(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# GaussianMixture(covariance_type='full', init_params='random', max_iter=10,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=1, reg_covar=1e-06, tol=1e-09, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
plot_gaussianmixture(15)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)
# GaussianMixture(covariance_type='full', init_params='random', max_iter=15,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=1, reg_covar=1e-06, tol=1e-09, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
plot_gaussianmixture(20)
# Out:
# GaussianMixture(covariance_type='full', init_params='random', max_iter=20,
#         means_init=None, n_components=2, n_init=1, precisions_init=None,
#         random_state=1, reg_covar=1e-06, tol=1e-09, verbose=0,
#         verbose_interval=10, warm_start=False, weights_init=None)

# %%
model1 = GaussianMixture(n_components=2, init_params='random', random_state=0, max_iter=20)
model1.fit(X)
gamma1 = model1.predict_proba(X)
gamma1
# Out:
# array([[ 0.50831878,  0.49168122],
#        [ 0.59560354,  0.40439646],
#        [ 0.49965018,  0.50034982],
#        ...,
#        [ 0.47946144,  0.52053856],
#        [ 0.48286938,  0.51713062],
#        [ 0.49474633,  0.50525367]])

# %% [markdown]
# gamma로 나온 값들이 각 점이 어디에 속할지 확률로 나타낸건가?
