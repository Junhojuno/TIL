# %%
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale

# %%
x = (np.arange(9,dtype='float') - 3).reshape(-1,1)
x = np.vstack([x,[20]])

# %%
df = pd.DataFrame(np.hstack([x, scale(x), robust_scale(x), 
                             minmax_scale(x), maxabs_scale(x)]),columns=['x','scale(x)','robust_scale(x)','minmax_scale(x)','maxabs_scale(x)'])
df.tail()
# Out:
#       x  scale(x)  robust_scale(x)  minmax_scale(x)  maxabs_scale(x)
# 5   2.0 -0.145067         0.111111         0.217391             0.10
# 6   3.0  0.016119         0.333333         0.260870             0.15
# 7   4.0  0.177304         0.555556         0.304348             0.20
# 8   5.0  0.338490         0.777778         0.347826             0.25
# 9  20.0  2.756273         4.111111         1.000000             1.00

# %%
from sklearn.preprocessing import normalize
from sklearn.datasets import load_iris

# %%
iris = load_iris()

data1 = iris.data[:,:2]
data2 = normalize(data1)

# %%
sns.jointplot(data1[:,0], data1[:,1])
plt.show()

# %%
sns.jointplot(data2[:,0], data2[:,1])
plt.show()

# %% [markdown]
# ##### one-hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
x = np.array([[0],[1],[2]])
x
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
ohe.fit(x)
ohe.n_values_, ohe.feature_indices_, ohe.active_features_
# Out:
# (array([3]), array([0, 3], dtype=int32), array([0, 1, 2], dtype=int64))
